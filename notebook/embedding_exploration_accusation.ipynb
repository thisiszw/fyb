# %%
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import pickle as pickle
# %matplotlib inline
# Out:
# /home/aida-zw/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# !nvidia-smi

# %% [markdown]
# ## data

# %%
path = "/home/aida-zw/Desktop/ws/Data/sample/"
path_io = "/home/aida-zw/Desktop/ws/notebook/io/"
def read_data(csv_file, path):
    df = pd.read_csv(path + csv_file)
    df = df[['fact', 'accusation']]
    return df
train_data = read_data('data_train.csv', path)
test_data = read_data('data_test.csv', path)
train_data.shape， test_data
# Out:
# ((154592, 2), (32508, 2))

# %%
min_count =100
df_tmp = train_data.groupby('accusation').filter(lambda x: len(x) > min_count).drop_duplicates(subset='accusation')
accusation_set = df_tmp.accusation.tolist()
accusation_set = [x for x in accusation_set if  ',' not in x]
train_data = train_data[train_data.accusation.isin(accusation_set)]
test_data = test_data[test_data.accusation.isin(accusation_set)]

train_data.shape, test_data.shape
# Out:
# ((117709, 2), (29569, 2))

# %%
label_encoder = LabelEncoder()
label_encoder.fit(train_data.accusation)

with open(path_io+'label_encoder_accu.pickle', 'wb') as handle:
    pickle.dump(label_encoder, handle, protocol=pickle.HIGHEST_PROTOCOL)

train_data.accusation = label_encoder.transform(train_data.accusation)
test_data.accusation = label_encoder.transform(test_data.accusation)

train_data.shape, test_data.shape, label_encoder.classes_.shape
# Out:
# ((117709, 2), (29569, 2), (122,))

# %% [markdown]
# ## model

# %%
train_data.accusation = train_data.accusation.map(int)
test_data.accusation = test_data.accusation.map(int)
train_input_fn = tf.estimator.inputs.pandas_input_fn(train_data, train_data['accusation'], shuffle=True, num_epochs=None, batch_size=512)
test_input_fn = tf.estimator.inputs.pandas_input_fn(test_data, test_data['accusation'], shuffle=False, batch_size=128)

# %%
tf.gfile.DeleteRecursively(path_io +'model/')

# %%
n_classes = len(accusation_set)
feature_columns = [hub.text_embedding_column('fact','https://tfhub.dev/google/nnlm-zh-dim128-with-normalization/1', trainable=True)]
model = tf.estimator.DNNClassifier([512, 512, 128], 
                                   feature_columns=feature_columns, n_classes=n_classes, model_dir=path_io+'model/')
model.train(input_fn=train_input_fn, max_steps=3000)
# Out:
# INFO:tensorflow:Using /tmp/tfhub_modules to cache modules.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/home/aida-zw/Desktop/ws/notebook/io/model/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fec0c6e9898>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable dnn/input_from_feature_columns/input_layer/fact_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/8a7d79f6fd9af6ea61fa3e11a09a79a613503992/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /home/aida-zw/Desktop/ws/notebook/io/model/model.ckpt.
# INFO:tensorflow:loss = 2474.2432, step = 0
# INFO:tensorflow:global_step/sec: 15.61
# INFO:tensorflow:loss = 1823.1154, step = 100 (6.408 sec)
# INFO:tensorflow:global_step/sec: 17.0787
# INFO:tensorflow:loss = 1493.658, step = 200 (5.855 sec)
# INFO:tensorflow:global_step/sec: 16.2282
# INFO:tensorflow:loss = 1609.8041, step = 300 (6.162 sec)
# INFO:tensorflow:global_step/sec: 16.8057
# INFO:tensorflow:loss = 1090.8804, step = 400 (5.950 sec)
# INFO:tensorflow:global_step/sec: 16.4329
# INFO:tensorflow:loss = 1350.9861, step = 500 (6.085 sec)
# INFO:tensorflow:global_step/sec: 16.4371
# INFO:tensorflow:loss = 407.4064, step = 600 (6.084 sec)
# INFO:tensorflow:global_step/sec: 16.5511
# INFO:tensorflow:loss = 1171.7583, step = 700 (6.042 sec)
# INFO:tensorflow:global_step/sec: 16.0973
# INFO:tensorflow:loss = 579.6587, step = 800 (6.212 sec)
# INFO:tensorflow:global_step/sec: 16.8365
# INFO:tensorflow:loss = 1010.52344, step = 900 (5.939 sec)
# INFO:tensorflow:global_step/sec: 16.13
# INFO:tensorflow:loss = 1067.1848, step = 1000 (6.200 sec)
# INFO:tensorflow:global_step/sec: 16.8806
# INFO:tensorflow:loss = 759.18726, step = 1100 (5.924 sec)
# INFO:tensorflow:global_step/sec: 16.112
# INFO:tensorflow:loss = 861.9067, step = 1200 (6.206 sec)
# INFO:tensorflow:global_step/sec: 16.4831
# INFO:tensorflow:loss = 221.11893, step = 1300 (6.067 sec)
# INFO:tensorflow:global_step/sec: 16.5149
# INFO:tensorflow:loss = 779.9052, step = 1400 (6.055 sec)
# INFO:tensorflow:global_step/sec: 16.1327
# INFO:tensorflow:loss = 296.87042, step = 1500 (6.199 sec)
# INFO:tensorflow:global_step/sec: 16.6715
# INFO:tensorflow:loss = 772.7132, step = 1600 (5.999 sec)
# INFO:tensorflow:global_step/sec: 16.1786
# INFO:tensorflow:loss = 640.42004, step = 1700 (6.181 sec)
# INFO:tensorflow:global_step/sec: 16.9962
# INFO:tensorflow:loss = 518.6913, step = 1800 (5.884 sec)
# INFO:tensorflow:global_step/sec: 16.2187
# INFO:tensorflow:loss = 603.82916, step = 1900 (6.166 sec)
# INFO:tensorflow:global_step/sec: 16.5148
# INFO:tensorflow:loss = 491.6196, step = 2000 (6.055 sec)
# INFO:tensorflow:global_step/sec: 16.3973
# INFO:tensorflow:loss = 436.44855, step = 2100 (6.099 sec)
# INFO:tensorflow:global_step/sec: 16.2589
# INFO:tensorflow:loss = 447.32803, step = 2200 (6.150 sec)
# INFO:tensorflow:global_step/sec: 16.7949
# INFO:tensorflow:loss = 368.96234, step = 2300 (5.954 sec)
# INFO:tensorflow:global_step/sec: 16.0465
# INFO:tensorflow:loss = 270.79825, step = 2400 (6.232 sec)
# INFO:tensorflow:global_step/sec: 16.9831
# INFO:tensorflow:loss = 278.23248, step = 2500 (5.888 sec)
# INFO:tensorflow:global_step/sec: 16.2626
# INFO:tensorflow:loss = 242.92807, step = 2600 (6.149 sec)
# INFO:tensorflow:global_step/sec: 16.9907
# INFO:tensorflow:loss = 231.12433, step = 2700 (5.886 sec)
# INFO:tensorflow:global_step/sec: 16.2612
# INFO:tensorflow:loss = 181.07779, step = 2800 (6.150 sec)
# INFO:tensorflow:global_step/sec: 16.5253
# INFO:tensorflow:loss = 87.26538, step = 2900 (6.051 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into /home/aida-zw/Desktop/ws/notebook/io/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 176.44911.

# %%
# %time test_predictions = list(model.predict(input_fn=test_input_fn))

# %% [markdown]
# ## Prediction

# %%
class Predictor(object):
    def __init__(self, model_dir, label_encoder, n_classes, df_accu_dir):
        self.model_dir = model_dir
        self.df_accu = pd.read_csv(df_accu_dir)
        self.label_encoder = label_encoder
        self.n_classes = n_classes
        self.feature_columns = [hub.text_embedding_column('fact',hub_dir , trainable=True)]
        self.model = tf.estimator.DNNClassifier([512, 512, 128], 
                        feature_columns=self.feature_columns, n_classes=self.n_classes, model_dir=self.model_dir)
    
    def predict(self, content):

        test_data = pd.DataFrame({'fact': content})
        ans_accusation, _ = self.predict_accu(test_data)
        ans_articles = self.predict_law(test_data)
        ans_imprisonment = self.predict_time(test_data)
        #print (len(ans_accusation), len(ans_articles), len(ans_imprisonment))
        ans = pd.DataFrame({'accusation':ans_accusation, 'articles': ans_articles, 'imprisonment':ans_imprisonment})
        dict_ans = ans.to_dict(orient='records')
        return dict_ans
        
    def predict_law(self, test_data):
        law = []
        for i in range(test_data.shape[0]):
            law.append([7])
        return law

        
        
    def predict_time(self, test_data):
        time = []
        for i in range(test_data.shape[0]):
            time.append(7)
        return time
    
    
    def predict_accu(self, test_data):
        test_input_fn = tf.estimator.inputs.pandas_input_fn(
            test_data, 
            None, 
            shuffle=False, 
            batch_size=128)
        result = list(self.model.predict(input_fn=test_input_fn))
        result_class = np.array([p['classes'][0] for p in result])
        prediction_arr = label_encoder.inverse_transform(result_class.astype(int))
        accusation_num = self.get_accusation_num(self.df_accu, prediction_arr)
        
        return accusation_num, prediction_arr
    
        
    
    
    def get_accusation_num(self, df_accu, arr):
        keys = df_accu.accusation.tolist()
        keys = [x.strip() for x in keys]
        values = df_accu.accusation_num.tolist()
        dict_accu = dict(zip(keys, values))

        accusation_num = list()
        for accu in arr:
            accusation_num.append([dict_accu.get(x.replace("'", "").strip()) for x in accu.split(',')])
        return accusation_num

# %% [markdown]
# ## if __name__ == "__main__":

# %%
n_classes = 122
model_dir = path_io + 'model/'
df_accu_dir = path_io + "accu.csv"
label_encoder_dir = path_io + 'label_encoder_accu.pickle'
hub_dir = path_io + 'google_nnlm-zh-dim128-with-normalization_1'


with open(label_encoder_dir, 'rb') as handle:
    label_encoder = pickle.load(handle)

content = test_data['fact'].tolist()    
    
model = Predictor(model_dir, label_encoder, n_classes, df_accu_dir)
result = model.predict(content)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/home/aida-zw/Desktop/ws/notebook/io/model/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fec0ce059b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable dnn/input_from_feature_columns/input_layer/fact_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/home/aida-zw/Desktop/ws/notebook/io/google_nnlm-zh-dim128-with-normalization_1/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/aida-zw/Desktop/ws/notebook/io/model/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# /home/aida-zw/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
result
# Out:
# [{'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [81], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [151], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [143], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [116], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [171], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [151], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [55], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [158], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [15], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [135], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [155], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [13], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [85], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [117], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [15], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [148], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [139], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [43], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [74], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [31], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [43], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [141], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [15], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [15], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [37], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [42], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [13], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [117], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [148], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [92], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [167], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [84], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [114], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [158], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [92], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [152], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [42], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [117], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [92], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [189], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [83], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [125], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [178], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [171], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [151], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [44], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [65], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [81], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [44], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [121], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [90], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [92], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [151], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [195], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [96], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [191], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [117], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [13], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [116], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [108], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [15], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [20], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [141], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [202], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [148], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [90], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [138], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [184], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [20], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [83], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [143], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [35], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [202], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [158], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [44], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [31], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [70], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [92], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [150], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [85], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [152], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [17], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [150], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [167], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [170], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [15], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [152], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [96], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [83], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [45], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [65], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [100], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [117], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [43], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [143], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [171], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [83], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [148], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [117], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [141], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [92], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [202], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [100], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [202], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [13], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [171], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [181], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [37], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [194], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [152], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [31], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [44], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [13], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [189], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [84], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [114], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [181], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [138], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [135], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [17], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [121], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [88], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [202], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [167], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [13], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [61], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [20], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [151], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [195], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [178], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [61], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [195], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [55], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [88], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [114], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [13], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [43], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [181], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [141], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [151], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [44], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [44], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [178], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [72], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [5], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [195], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [121], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [31], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [55], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [139], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [142], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [195], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [123], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [92], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [171], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [26], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [169], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [21], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [136], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [151], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [158], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [11], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [58], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [87], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [128], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [31], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [9], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [161], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [117], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [118], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [173], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [109], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [25], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [90], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [39], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [49], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [51], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [55], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [63], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [171], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [195], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [201], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [8], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [23], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [182], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [147], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [197], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [192], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [156], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [99], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [77], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [93], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [68], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [66], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [162], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [195], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [71], 'articles': [7], 'imprisonment': 7},
#  {'accusation': [101], 'articles': [7], 'imprisonment': 7},
#  ...]

# %%
    def predict(self, content):
        result = []
        for a in range(0, len(content)):
            result.append({
                "accusation": [1, 2, 3],
                "imprisonment": 5,
                "articles": [5, 7, 9]
            })
        return result

# %%
yhat = np.array([p['classes'][0] for p in test_predictions])
y = test_data.accusation
cm = pd.DataFrame({'truth': label_encoder.inverse_transform(y.values.astype(int)), 
                   'prediction': label_encoder.inverse_transform(yhat.astype(int))})
pd.pivot_table(cm, index='truth', columns='prediction', aggfunc='size').iloc[5:10,5:10]

# %%
result[0]

# %%
yhat = np.array([p['classes'][0] for p in test_predictions])
y = test_data.accusation
cm = pd.DataFrame({'truth': label_encoder.inverse_transform(y.values.astype(int)), 
                   'prediction': label_encoder.inverse_transform(yhat.astype(int))})
pd.pivot_table(cm, index='truth', columns='prediction', aggfunc='size').iloc[5:10,5:10]

# %%
cm.to_csv("../output/result.csv", index=False)

# %%
class BaselineModel(object):
    def __init__(self):
        pass
    def predict(self, df):
        theft = df.fact.str.contains('盗')
        yhat = df.accusation.copy()
        yhat[theft] = 1
        yhat[~theft] = 0
        return yhat

# %%
base_model = BaselineModel()
yyhat = base_model.predict(test_data)

# %%
# y = test_data.accusation
# cm = pd.DataFrame({'truth': label_encoder.inverse_transform(y.values.astype(int)), 
#                    'prediction': label_encoder.inverse_transform(yyhat.astype(int))})
# pd.pivot_table(cm, index='truth', columns='prediction', aggfunc='size')

# %%
path_io = "/home/aida-zw/Desktop/ws/notebook/io/"
